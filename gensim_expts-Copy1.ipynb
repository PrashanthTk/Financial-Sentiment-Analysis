# %%
import glob
import pandas as pd
import numpy
def read_dataframe(path):
    #A substitute for read_data function.
    dflist=[]
    for filename in glob.glob(dirpath+"*.csv"):
        dflist.append(pd.read_csv(path,header=0))
    traindf=pd.concat(dflist)
    traindf.describe()
    examples=[]
    for indx,row in traindf.iterrows():
        label=row['Sentiment']
        sentence=row['Phrase']
        examples.append((sentence,label))
    #print(traindf.columns)
    #labels=traindf['Sentiment'].values
    #train_labels=to_categorical(numpy.asarray(labels),num_classes=5)
    return zip(*examples)
    #return traindf
    
    
def TransferLearn(model=None,dirpath="taggedCalls/"):
    #oldmodel=keras.model.load_model("modelpath")
    newmodel,newembeddings=compile_lstm(embeddings,lstm_shape,lstm_settings)
temp=TransferLearn()
temp.head()
# Out:
# Index(['Phrase', 'Sentiment'], dtype='object')
#                                               Phrase  Sentiment
# 0  welcome to the bwg strategy Conference Center ...          3
# 1  everybody Gregor when he repeated eug and than...          3
# 2  and you've left that rolls in the past 12 mont...          1
# 3  I want to breathe information that is Cher tod...          1
# 4  and if you're actively employee of Ole Miss Re...          3

# %%
temp.describe()
# Out:
#         Sentiment
# count  390.000000
# mean     2.161538
# std      0.773639
# min      0.000000
# 25%      2.000000
# 50%      2.000000
# 75%      2.000000
# max      4.000000

# %%
from nltk.corpus import switchboard
 
data = []
 
for fileid in brown.fileids():
    document = ' '.join(brown.words(fileid))
    data.append(document)
 
NO_DOCUMENTS = len(data)
print(NO_DOCUMENTS)
print(data[:2])
# Out:
# 500
# ...

# %%
import glob
import numpy

# %%
import re
from gensim import models, corpora
from nltk import word_tokenize
from nltk.corpus import stopwords
from sense2vec import Sense2VecComponent
import spacy
NUM_TOPICS = 5
STOPWORDS = stopwords.words('english')
 
def clean_text(text):
    
    tokenized_text = word_tokenize(text.lower())
    
    
    cleaned_text = [t for t in tokenized_text if t not in STOPWORDS and re.match('[a-zA-Z\-][a-zA-Z\-]{2,}', t)]
    return cleaned_text
 
# For gensim we need to tokenize the data and filter out stopwords
tokenized_data = []
"""
for text in data:
    cleaned_text=clean_text(text)
    doc=nlp(cleaned_text)
    tokenized_data.append()"""


"""nlp = spacy.load('en')  # make sure to use larger model!
s2v=Sense2VecComponent('reddit_vectors-1.1.0')
nlp.add_pipe(s2v)
file=open('fullText/a2c47189-bfaa-4f7c-adca-d60e316319d4.txt','r').read()"""
#doc=nlp(file)
data=[]
"""for transfile in glob.glob("./fullText/*.txt"):
    file=open(transfile,'r').read()
    data.append(file)
    doc=nlp(file)
    toklist=[]
    for token in doc.ents:
        toklist.append(token.text)
    tokenized_data.append(toklist)"""
    
print('Shape of data'+str(numpy.array(data).shape))
"""for sent in doc.sents:
    tokens=nlp(sent.text)
    toklist=[]
    data.append(sent.text)
    for tok in tokens.ents:
        if tok.text not in STOPWORDS:
            toklist.append(tok.text)
    tokenized_data.append(toklist)
"""
# Build a Dictionary - association word to numeric id
tokenized_data=["is","the","baap","Los Angeles"]
dictionary = corpora.Dictionary(tokenized_data)
 
# Transform the collection of texts to a numerical form
corpus = [dictionary.doc2bow(text) for text in tokenized_data]
 
# Have a look at how the 20th document looks like: [(word_id, count), ...]
print(corpus[20])
# [(12, 3), (14, 1), (21, 1), (25, 5), (30, 2), (31, 5), (33, 1), (42, 1), (43, 2),  ...
 
# Build the LDA model
# Out:
# <input>:17: DeprecationWarning: invalid escape sequence \-
# <input>:17: DeprecationWarning: invalid escape sequence \-
# <input>:17: DeprecationWarning: invalid escape sequence \-
# <ipython-input-46-e3d0072a62ee>:17: DeprecationWarning: invalid escape sequence \-
#   cleaned_text = [t for t in tokenized_text if t not in STOPWORDS and re.match('[a-zA-Z\-][a-zA-Z\-]{2,}', t)]
# Shape of data(165,)
# ...

# %%
NO_DOCUMENTS=len(tokenized_data)
NUM_TOPICS=10

# %%
print("LDA Model:")
 
for idx in range(NUM_TOPICS):
    # Print the first 10 most representative topics
    print("Topic #%s:" % idx, lda_model.print_topic(idx, 10))
 
print("=" * 20)
 
print("LSI Model:")
 
for idx in range(NUM_TOPICS):
    # Print the first 10 most representative topics
    print("Topic #%s:" % idx, lsi_model.print_topic(idx, 10))
 
print("=" * 20)
# Out:
# LDA Model:
# Topic #0: 0.036*"'s" + 0.015*"I" + 0.014*"." + 0.013*"got" + 0.011*"likely" + 0.010*"going" + 0.008*"way" + 0.007*"able" + 0.006*"changes" + 0.006*"go"
# Topic #1: 0.011*"I" + 0.009*"Bitcoin" + 0.009*"," + 0.009*"kind" + 0.009*"okay" + 0.007*"build" + 0.005*"think" + 0.005*"going" + 0.005*"n't" + 0.005*"right"
# Topic #2: 0.052*"I" + 0.045*"'s" + 0.028*"think" + 0.025*"lot" + 0.020*"going" + 0.009*"n't" + 0.008*"really" + 0.008*"-" + 0.007*"something" + 0.007*"see"
# Topic #3: 0.043*"I" + 0.035*"'s" + 0.021*"going" + 0.012*"'m" + 0.012*"n't" + 0.009*"get" + 0.009*"think" + 0.009*"today" + 0.007*"know" + 0.007*"much"
# Topic #4: 0.028*"'s" + 0.022*"I" + 0.019*"'re" + 0.016*"going" + 0.012*"terms" + 0.012*"see" + 0.011*"n't" + 0.009*"much" + 0.009*"get" + 0.009*"start"
# Topic #5: 0.036*"I" + 0.018*"see" + 0.015*"Bitcoin" + 0.013*"'s" + 0.010*"think" + 0.009*"let" + 0.007*"kind" + 0.007*"got" + 0.005*"n't" + 0.005*"seeing"
# ...

# %%
text = "The economy is working better than ever"
bow = dictionary.doc2bow(clean_text(text))
 
print(lsi_model[bow])
# [(0, 0.091615426138426506), (1, -0.0085557463300508351), (2, 0.016744863677828108), (3, 0.040508186718598529), (4, 0.014201267714185898), (5, -0.012208538275305329), (6, 0.031254053085582149), (7, 0.017529584659403553), (8, 0.056957633371540077),
#(9, 0.025989149894888153)]
 
print(lda_model[bow])
# Out:
# [(0, 0.015914397684933915), (1, -0.012557998544013805), (2, -0.0016324846468196569), (3, 0.012921390206682037), (4, 0.014416062190275462), (5, 0.02270120800461742), (6, -0.013621828150574857), (7, -0.025762960899187323), (8, 0.00218905161806875), (9, 0.058672511346548516)]
# [(0, 0.033333335), (1, 0.033333335), (2, 0.03333656), (3, 0.033339266), (4, 0.69997925), (5, 0.033333335), (6, 0.03334443), (7, 0.033333335), (8, 0.033333603), (9, 0.033333573)]

# %%
from gensim import similarities
 
lda_index = similarities.MatrixSimilarity(lda_model[corpus])
 
# Let's perform some queries
similarities = lda_index[lda_model[bow]]
# Sort the similarities
similarities = sorted(enumerate(similarities), key=lambda item: -item[1])
 
# Top most similar documents:
print(similarities[:10])
# [(104, 0.87591344), (178, 0.86124849), (31, 0.8604598), (77, 0.84932965), (85, 0.84843522), (135, 0.84421808), (215, 0.84184396), (353, 0.84038532), (254, 0.83498049), (13, 0.82832891)]
 
# Let's see what's the most similar document
document_id, similarity = similarities[0]
print(data[document_id][:1000])
# Out:
# [(383, 1.0000001), (64, 1.0), (312, 1.0), (167, 0.9989678), (374, 0.99763083), (50, 0.99763066), (108, 0.99763006), (125, 0.99763006), (235, 0.99654555), (149, 0.9965451)]
# thank you very much

# %%
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer
 
NUM_TOPICS = 10
 
vectorizer = CountVectorizer(min_df=5, max_df=0.9, 
                             stop_words='english', lowercase=True, 
                             token_pattern='[a-zA-Z\-][a-zA-Z\-]{2,}')
data_vectorized = vectorizer.fit_transform(data)
 
# Build a Latent Dirichlet Allocation Model
lda_model = LatentDirichletAllocation(n_topics=NUM_TOPICS, max_iter=10, learning_method='online')
lda_Z = lda_model.fit_transform(data_vectorized)
 
text = "The economy is working better than ever"
x = lda_model.transform(vectorizer.transform([text]))[0]
print(x, x.sum())
# Out:
# /Users/prashanththekkada/.virtualenvs/dl4cv/lib/python3.6/site-packages/sklearn/decomposition/online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# [0.05       0.05       0.0500001  0.05       0.05       0.54998849
#  0.05       0.05       0.0500114  0.05      ] 0.9999999999999999

# %%
import pyLDAvis.sklearn
 
pyLDAvis.enable_notebook()
panel = pyLDAvis.sklearn.prepare(lda_model, data_vectorized, vectorizer, mds='tsne')
panel
# Out:
# /Users/prashanththekkada/.virtualenvs/dl4cv/lib/python3.6/site-packages/pyLDAvis/_prepare.py:387: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   topic_term_dists = topic_term_dists.ix[topic_order]
# PreparedData(topic_coordinates=            Freq  cluster  topics           x           y
# topic
# 3      21.592209        1       1  -45.961250 -284.647217
# 2      18.997723        1       2   88.491295  -89.715553
# 9      14.293122        1       3    1.996316   80.886818
# 6       8.714577        1       4 -146.540039 -101.648369
# 1       8.139535        1       5  236.933746   92.772797
# 7       7.183912        1       6  136.634003  275.861725
# 5       6.321816        1       7  185.494034 -280.789124
# 4       6.126778        1       8  -94.798630  272.065460
# ...

# %%
"""file=open('fullText/a2c47189-bfaa-4f7c-adca-d60e316319d4.txt','r').read()
doc=nlp(file)
for token in doc:
    tokenized_data.append(token.text)
print(tokenized_data)"""
data_vectorized.shape
# Out:
# (390, 131)

# %%
lda_model = models.LdaModel(corpus=corpus, num_topics=NUM_TOPICS, id2word=dictionary)
 
# Build the LSI model
#lsi_model = models.LsiModel(corpus=corpus, num_topics=NUM_TOPICS, id2word=dictionary)

# %%
import pyLDAvis.gensim
panel2 = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary)
panel2
# Out:
# /Users/prashanththekkada/.virtualenvs/dl4cv/lib/python3.6/site-packages/pyLDAvis/_prepare.py:387: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   topic_term_dists = topic_term_dists.ix[topic_order]
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 1      46.464966        1       1 -0.001299  0.028073
# 2      19.350634        1       2  0.014166 -0.013143
# 3      11.958345        1       3 -0.029875 -0.009385
# 4      11.273579        1       4  0.006812  0.000346
# 0      10.952482        1       5  0.010196 -0.005892, topic_info=      Category         Freq                Term        Total  loglift  logprob
# term
# 225    Default  1017.000000              Amazon  1017.000000  30.0000  30.0000
# ...
